# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from cycler import cycler
import numpy as np
import yfinance as yf
import plotly.express as px 
rcParams['figure.figsize'] = 18, 5
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
rcParams['axes.prop_cycle'] = cycler(color=['#365977'])
rcParams['lines.linewidth'] = 2.5

# %%
ng = yf.download('NG=F', start='2006-04-06', end='2022-1-24')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ng
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2006-04-06  7.080  7.250  6.950  6.972      6.972   30067
# 2006-04-07  6.949  6.949  6.720  6.743      6.743   36415
# 2006-04-10  6.726  6.940  6.650  6.882      6.882   31637
# 2006-04-11  6.919  7.020  6.790  6.908      6.908   33399
# 2006-04-12  6.907  7.000  6.770  6.808      6.808   27111
# ...           ...    ...    ...    ...        ...     ...
# 2022-01-18  4.356  4.390  4.216  4.283      4.283  119454
# 2022-01-19  4.327  4.385  4.010  4.031      4.031  116542
# 2022-01-20  4.015  4.037  3.781  3.802      3.802  104199
# 2022-01-21  3.838  4.044  3.833  3.999      3.999   70256
# 2022-01-24  3.915  4.068  3.876  4.027      4.027   47100
#
# [3977 rows x 6 columns]

# %%
ng.drop(columns=(['Open','High','Low','Adj Close','Volume']), inplace=True)
ng
# Out:
#             Close
# Date
# 2006-04-06  6.972
# 2006-04-07  6.743
# 2006-04-10  6.882
# 2006-04-11  6.908
# 2006-04-12  6.808
# ...           ...
# 2022-01-18  4.283
# 2022-01-19  4.031
# 2022-01-20  3.802
# 2022-01-21  3.999
# 2022-01-24  4.027
#
# [3977 rows x 1 columns]

# %%
#ng.to_csv('ng.csv')

# %%
ng_fig = px.line(ng)
ng_fig.show()
# Out:
# <div>                            <div id="b8c5f0cf-3d3d-49a5-aef4-460c9615cb9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8c5f0cf-3d3d-49a5-aef4-460c9615cb9c")) {                    Plotly.newPlot(                        "b8c5f0cf-3d3d-49a5-aef4-460c9615cb9c",                        [{"hovertemplate": "variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Close", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Close", "showlegend": true, "type": "scattergl", "x": ["2006-04-06T00:00:00", "2006-04-07T00:00:00", "2006-04-10T00:00:00", "2006-04-11T00:00:00", "2006-04-12T00:00:00", "2006-04-13T00:00:00", "2006-04-17T00:00:00", "2006-04-18T00:00:00", "2006-04-19T00:00:00", "2006-04-20T00:00:00", "2006-0
# ...

# %%
ten_bond =  yf.download('ZN=F', start='2006-04-06', end='2022-1-24')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ten_bond
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2006-04-06  106.468750  106.484375  106.109375  106.234375  106.234375
# 2006-04-07  106.171875  106.406250  105.687500  105.828125  105.828125
# 2006-04-10  105.687500  105.921875  105.640625  105.843750  105.843750
# 2006-04-11  105.890625  106.109375  105.890625  106.046875  106.046875
# 2006-04-12  106.062500  106.234375  105.671875  105.734375  105.734375
# ...                ...         ...         ...         ...         ...
# 2022-01-18  128.031250  128.046875  127.250000  127.375000  127.375000
# 2022-01-19  127.296875  127.734375  127.062500  127.671875  127.671875
# 2022-01-20  127.343750  127.953125  127.250000  127.703125  127.703125
# 2022-01-21  127.906250  128.500000  127.875000  128.312500  128.312500
# 2022-01-24  128.218750  128.703125  127.984375  128.515625  128.515625
#
#              Volume
# Date
# 2006-04-06  1222750
# 2006-04-07   550574
# 2006-04-10   522067
# ...

# %%
ten_bond.drop(columns=(['Open','High','Low','Adj Close','Volume']), inplace=True)
ten_bond
# Out:
#                  Close
# Date
# 2006-04-06  106.234375
# 2006-04-07  105.828125
# 2006-04-10  105.843750
# 2006-04-11  106.046875
# 2006-04-12  105.734375
# ...                ...
# 2022-01-18  127.375000
# 2022-01-19  127.671875
# 2022-01-20  127.703125
# 2022-01-21  128.312500
# 2022-01-24  128.515625
#
# [3966 rows x 1 columns]

# %%
ten_bond.to_csv('ten.csv')

# %%
ten_fig = px.line(ten_bond)
ten_fig.show()
# Out:
# <div>                            <div id="63dae1c9-c887-4d59-98fb-7811ad0f24ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63dae1c9-c887-4d59-98fb-7811ad0f24ba")) {                    Plotly.newPlot(                        "63dae1c9-c887-4d59-98fb-7811ad0f24ba",                        [{"hovertemplate": "variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Close", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Close", "showlegend": true, "type": "scattergl", "x": ["2006-04-06T00:00:00", "2006-04-07T00:00:00", "2006-04-10T00:00:00", "2006-04-11T00:00:00", "2006-04-12T00:00:00", "2006-04-13T00:00:00", "2006-04-17T00:00:00", "2006-04-18T00:00:00", "2006-04-19T00:00:00", "2006-04-20T00:00:00", "2006-0
# ...

# %%
five_bond =  yf.download('ZF=F', start='2006-04-06', end='2022-1-24')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
five_bond
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2006-04-06  104.531250  104.546875  104.328125  104.406250  104.406250
# 2006-04-07  104.359375  104.515625  104.046875  104.156250  104.156250
# 2006-04-10  104.062500  104.218750  104.015625  104.171875  104.171875
# 2006-04-11  104.203125  104.328125  104.187500  104.281250  104.281250
# 2006-04-12  104.281250  104.390625  104.062500  104.109375  104.109375
# ...                ...         ...         ...         ...         ...
# 2022-01-18  119.460938  119.460938  118.937500  119.015625  119.015625
# 2022-01-19  118.953125  119.242188  118.789062  119.203125  119.203125
# 2022-01-20  118.984375  119.343750  118.914062  119.179688  119.179688
# 2022-01-21  119.304688  119.640625  119.296875  119.562500  119.562500
# 2022-01-24  119.500000  119.835938  119.304688  119.742188  119.742188
#
#              Volume
# Date
# 2006-04-06   568267
# 2006-04-07   284488
# 2006-04-10   215862
# ...

# %%
five_bond.drop(columns=(['Open','High','Low','Adj Close','Volume']), inplace=True)
five_bond
# Out:
#                  Close
# Date
# 2006-04-06  104.406250
# 2006-04-07  104.156250
# 2006-04-10  104.171875
# 2006-04-11  104.281250
# 2006-04-12  104.109375
# ...                ...
# 2022-01-18  119.015625
# 2022-01-19  119.203125
# 2022-01-20  119.179688
# 2022-01-21  119.562500
# 2022-01-24  119.742188
#
# [3978 rows x 1 columns]

# %%
five_bond.to_csv('five.csv')

# %%
five_fig = px.line(five_bond)
five_fig.show()
# Out:
# <div>                            <div id="189a1038-8c86-43ba-93ad-b1e58c8edc62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("189a1038-8c86-43ba-93ad-b1e58c8edc62")) {                    Plotly.newPlot(                        "189a1038-8c86-43ba-93ad-b1e58c8edc62",                        [{"hovertemplate": "variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Close", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Close", "showlegend": true, "type": "scattergl", "x": ["2006-04-06T00:00:00", "2006-04-07T00:00:00", "2006-04-10T00:00:00", "2006-04-11T00:00:00", "2006-04-12T00:00:00", "2006-04-13T00:00:00", "2006-04-17T00:00:00", "2006-04-18T00:00:00", "2006-04-19T00:00:00", "2006-04-20T00:00:00", "2006-0
# ...

# %%
two_bond =  yf.download('ZT=F', start='2006-04-06', end='2022-1-24')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
two_bond
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2006-04-06  101.953125  101.960938  101.890625  101.921875  101.921875  139419
# 2006-04-07  101.906250  101.945312  101.765625  101.820312  101.820312   74605
# 2006-04-10  101.765625  101.835938  101.718750  101.820312  101.820312   51305
# 2006-04-11  101.835938  101.875000  101.812500  101.851562  101.851562   73182
# 2006-04-12  101.851562  101.898438  101.773438  101.789062  101.789062  106011
# ...                ...         ...         ...         ...         ...     ...
# 2022-01-18  108.625000  108.625000  108.441406  108.484375  108.484375  609371
# 2022-01-19  108.476562  108.566406  108.417969  108.527344  108.527344  454245
# 2022-01-20  108.449219  108.539062  108.437500  108.476562  108.476562  364586
# 2022-01-21  108.519531  108.617188  108.515625  108.605469  108.605469  475079
# 2022-01-24  108.582031  108.730469  108.515625  108.695312  108.695312  717444
#
# ...

# %%
two_bond.drop(columns=(['Open','High','Low','Adj Close','Volume']), inplace=True)
two_bond
# Out:
#                  Close
# Date
# 2006-04-06  101.921875
# 2006-04-07  101.820312
# 2006-04-10  101.820312
# 2006-04-11  101.851562
# 2006-04-12  101.789062
# ...                ...
# 2022-01-18  108.484375
# 2022-01-19  108.527344
# 2022-01-20  108.476562
# 2022-01-21  108.605469
# 2022-01-24  108.695312
#
# [3978 rows x 1 columns]

# %%
two_bond.to_csv('two.csv')

# %%
two_fig = px.line(two_bond)
two_fig.show()
# Out:
# <div>                            <div id="b5ee282e-7e34-42f3-9bea-8d289a193333" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5ee282e-7e34-42f3-9bea-8d289a193333")) {                    Plotly.newPlot(                        "b5ee282e-7e34-42f3-9bea-8d289a193333",                        [{"hovertemplate": "variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Close", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Close", "showlegend": true, "type": "scattergl", "x": ["2006-04-06T00:00:00", "2006-04-07T00:00:00", "2006-04-10T00:00:00", "2006-04-11T00:00:00", "2006-04-12T00:00:00", "2006-04-13T00:00:00", "2006-04-17T00:00:00", "2006-04-18T00:00:00", "2006-04-19T00:00:00", "2006-04-20T00:00:00", "2006-0
# ...

# %%
gold = yf.download('GC=F', start='2006-04-06', end='2022-1-24')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gold
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2006-04-06   588.000000   595.599976   588.000000   595.200012   595.200012
# 2006-04-07   595.500000   598.299988   585.500000   588.400024   588.400024
# 2006-04-10   589.000000   599.000000   589.000000   597.599976   597.599976
# 2006-04-11   602.000000   604.000000   595.000000   595.200012   595.200012
# 2006-04-12   597.299988   600.000000   597.299988   597.500000   597.500000
# ...                 ...          ...          ...          ...          ...
# 2022-01-18  1816.800049  1820.099976  1812.300049  1812.300049  1812.300049
# 2022-01-19  1817.400024  1843.099976  1817.400024  1843.099976  1843.099976
# 2022-01-20  1840.599976  1843.000000  1838.199951  1842.500000  1842.500000
# 2022-01-21  1838.000000  1842.400024  1828.900024  1831.800049  1831.800049
# 2022-01-24  1837.900024  1842.099976  1837.900024  1841.699951  1841.699951
#
#             Volume
# Date
# 2006-04-06     855
# ...

# %%
gold.drop(columns=(['Open','High','Low','Adj Close','Volume']), inplace=True)
gold
# Out:
#                   Close
# Date
# 2006-04-06   595.200012
# 2006-04-07   588.400024
# 2006-04-10   597.599976
# 2006-04-11   595.200012
# 2006-04-12   597.500000
# ...                 ...
# 2022-01-18  1812.300049
# 2022-01-19  1843.099976
# 2022-01-20  1842.500000
# 2022-01-21  1831.800049
# 2022-01-24  1841.699951
#
# [3976 rows x 1 columns]

# %%
#gold.to_csv('gold.csv')

# %%
gold_fig = px.line(gold)
gold_fig.show()
# Out:
# <div>                            <div id="8932d543-b99f-4c60-b775-8d027d5a819e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8932d543-b99f-4c60-b775-8d027d5a819e")) {                    Plotly.newPlot(                        "8932d543-b99f-4c60-b775-8d027d5a819e",                        [{"hovertemplate": "variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Close", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Close", "showlegend": true, "type": "scattergl", "x": ["2006-04-06T00:00:00", "2006-04-07T00:00:00", "2006-04-10T00:00:00", "2006-04-11T00:00:00", "2006-04-12T00:00:00", "2006-04-13T00:00:00", "2006-04-17T00:00:00", "2006-04-18T00:00:00", "2006-04-19T00:00:00", "2006-04-20T00:00:00", "2006-0
# ...

# %%
silver = yf.download('SI=F', start='2006-04-06', end='2022-1-24')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
silver
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2006-04-06  11.960000  12.007000  11.960000  12.007000  12.007000     115
# 2006-04-07  12.120000  12.120000  12.035000  12.035000  12.035000     117
# 2006-04-10  12.300000  12.580000  12.300000  12.529000  12.529000      32
# 2006-04-11  12.945000  12.945000  12.573000  12.573000  12.573000      53
# 2006-04-12  12.590000  12.636000  12.590000  12.636000  12.636000       2
# ...               ...        ...        ...        ...        ...     ...
# 2022-01-18  23.400000  23.487000  23.400000  23.487000  23.487000     207
# 2022-01-19  24.226000  24.226000  24.226000  24.226000  24.226000       3
# 2022-01-20  24.711000  24.711000  24.711000  24.711000  24.711000      21
# 2022-01-21  24.313999  24.313999  24.313999  24.313999  24.313999      17
# 2022-01-24  23.795000  23.795000  23.795000  23.795000  23.795000       0
#
# [3976 rows x 6 columns]

# %%
silver.drop(columns=(['Open','High','Low','Adj Close','Volume']), inplace=True)
silver
# Out:
#                 Close
# Date
# 2006-04-06  12.007000
# 2006-04-07  12.035000
# 2006-04-10  12.529000
# 2006-04-11  12.573000
# 2006-04-12  12.636000
# ...               ...
# 2022-01-18  23.487000
# 2022-01-19  24.226000
# 2022-01-20  24.711000
# 2022-01-21  24.313999
# 2022-01-24  23.795000
#
# [3976 rows x 1 columns]

# %%
#silver.to_csv('silver.csv')

# %%
silver_fig = px.line(silver)
silver_fig.show()
# Out:
# <div>                            <div id="02c9ff7f-b110-411c-8d67-fe18464fc43b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02c9ff7f-b110-411c-8d67-fe18464fc43b")) {                    Plotly.newPlot(                        "02c9ff7f-b110-411c-8d67-fe18464fc43b",                        [{"hovertemplate": "variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Close", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Close", "showlegend": true, "type": "scattergl", "x": ["2006-04-06T00:00:00", "2006-04-07T00:00:00", "2006-04-10T00:00:00", "2006-04-11T00:00:00", "2006-04-12T00:00:00", "2006-04-13T00:00:00", "2006-04-17T00:00:00", "2006-04-18T00:00:00", "2006-04-19T00:00:00", "2006-04-20T00:00:00", "2006-0
# ...

# %%
spy = yf.download('ES=F', start='2006-04-06', end='2022-1-24')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy
# Out:
#                Open     High      Low    Close  Adj Close   Volume
# Date
# 2006-04-06  1319.00  1320.50  1310.00  1317.50    1317.50   888393
# 2006-04-07  1317.00  1324.00  1301.25  1304.00    1304.00  1343220
# 2006-04-10  1303.75  1308.75  1300.25  1305.50    1305.50   727289
# 2006-04-11  1305.75  1307.75  1289.25  1294.00    1294.00  1105250
# 2006-04-12  1294.00  1298.25  1292.50  1295.50    1295.50   637521
# ...             ...      ...      ...      ...        ...      ...
# 2022-01-18  4666.00  4671.75  4560.00  4571.25    4571.25  2268240
# 2022-01-19  4577.75  4603.00  4517.25  4524.25    4524.25  2001348
# 2022-01-20  4526.00  4594.25  4437.75  4474.75    4474.75  2040704
# 2022-01-21  4454.25  4487.00  4381.25  4390.00    4390.00  3012106
# 2022-01-24  4389.00  4427.50  4212.75  4403.75    4403.75  3846785
#
# [3981 rows x 6 columns]

# %%
spy.drop(columns=(['Open','High','Low','Adj Close','Volume']), inplace=True)
spy
# Out:
#               Close
# Date
# 2006-04-06  1317.50
# 2006-04-07  1304.00
# 2006-04-10  1305.50
# 2006-04-11  1294.00
# 2006-04-12  1295.50
# ...             ...
# 2022-01-18  4571.25
# 2022-01-19  4524.25
# 2022-01-20  4474.75
# 2022-01-21  4390.00
# 2022-01-24  4403.75
#
# [3981 rows x 1 columns]

# %%
spy.to_csv('spy.csv')

# %%
spy_fig = px.line(spy)
spy_fig.show()
# Out:
# <div>                            <div id="0200bd70-94f6-42dd-99e6-5ee96160cb0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0200bd70-94f6-42dd-99e6-5ee96160cb0c")) {                    Plotly.newPlot(                        "0200bd70-94f6-42dd-99e6-5ee96160cb0c",                        [{"hovertemplate": "variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Close", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Close", "showlegend": true, "type": "scattergl", "x": ["2006-04-06T00:00:00", "2006-04-07T00:00:00", "2006-04-10T00:00:00", "2006-04-11T00:00:00", "2006-04-12T00:00:00", "2006-04-13T00:00:00", "2006-04-17T00:00:00", "2006-04-18T00:00:00", "2006-04-19T00:00:00", "2006-04-20T00:00:00", "2006-0
# ...

# %%
dow = yf.download('YM=F', start='2006-04-06', end='2022-1-24') 
dow
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2006-04-06  11286.0  11307.0  11223.0  11279.0    11279.0  145475
# 2006-04-07  11279.0  11328.0  11163.0  11184.0    11184.0   88453
# 2006-04-10  11181.0  11242.0  11164.0  11208.0    11208.0  120423
# 2006-04-11  11220.0  11238.0  11098.0  11144.0    11144.0   80665
# 2006-04-12  11147.0  11193.0  11135.0  11178.0    11178.0   81382
# ...             ...      ...      ...      ...        ...     ...
# 2022-01-18  35856.0  35901.0  35135.0  35259.0    35259.0  322172
# 2022-01-19  35301.0  35430.0  34883.0  34910.0    34910.0  296130
# 2022-01-20  34953.0  35379.0  34407.0  34616.0    34616.0  272488
# 2022-01-21  34556.0  34782.0  34100.0  34157.0    34157.0  335699
# 2022-01-24  34143.0  34410.0  33031.0  34253.0    34253.0  465699
#
# [3977 rows x 6 columns]

# %%
dow.drop(columns=(['Open','High','Low','Adj Close','Volume']), inplace=True)
dow
# Out:
#               Close
# Date
# 2006-04-06  11279.0
# 2006-04-07  11184.0
# 2006-04-10  11208.0
# 2006-04-11  11144.0
# 2006-04-12  11178.0
# ...             ...
# 2022-01-18  35259.0
# 2022-01-19  34910.0
# 2022-01-20  34616.0
# 2022-01-21  34157.0
# 2022-01-24  34253.0
#
# [3977 rows x 1 columns]

# %%
dow.to_csv('dow.csv')

# %%
dow_fig = px.line(dow)
dow_fig.show()
# Out:
# <div>                            <div id="f3f7f108-b9c1-4343-b582-f74fa502299b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3f7f108-b9c1-4343-b582-f74fa502299b")) {                    Plotly.newPlot(                        "f3f7f108-b9c1-4343-b582-f74fa502299b",                        [{"hovertemplate": "variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Close", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Close", "showlegend": true, "type": "scattergl", "x": ["2006-04-06T00:00:00", "2006-04-07T00:00:00", "2006-04-10T00:00:00", "2006-04-11T00:00:00", "2006-04-12T00:00:00", "2006-04-13T00:00:00", "2006-04-17T00:00:00", "2006-04-18T00:00:00", "2006-04-19T00:00:00", "2006-04-20T00:00:00", "2006-0
# ...

# %%
nas = yf.download('NQ=F', start='2006-04-06', end='2022-1-24') 
nas
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2006-04-06   1746.75   1761.25   1742.00   1754.75    1754.75   302618
# 2006-04-07   1753.25   1765.75   1735.00   1739.75    1739.75   363528
# 2006-04-10   1737.25   1743.00   1726.50   1735.50    1735.50   209544
# 2006-04-11   1735.50   1739.50   1709.50   1720.75    1720.75   334316
# 2006-04-12   1720.25   1724.25   1713.50   1718.75    1718.75   207308
# ...              ...       ...       ...       ...        ...      ...
# 2022-01-18  15616.75  15653.25  15170.75  15206.00   15206.00   868066
# 2022-01-19  15238.75  15372.00  15011.25  15033.50   15033.50   776612
# 2022-01-20  15042.25  15340.25  14646.75  14841.00   14841.00   771410
# 2022-01-21  14722.00  14858.50  14408.50  14426.50   14426.50  1041723
# 2022-01-24  14410.00  14582.00  13706.00  14501.00   14501.00  1323080
#
# [3981 rows x 6 columns]

# %%
nas.drop(columns=(['Open','High','Low','Adj Close','Volume']), inplace=True)
nas
# Out:
#                Close
# Date
# 2006-04-06   1754.75
# 2006-04-07   1739.75
# 2006-04-10   1735.50
# 2006-04-11   1720.75
# 2006-04-12   1718.75
# ...              ...
# 2022-01-18  15206.00
# 2022-01-19  15033.50
# 2022-01-20  14841.00
# 2022-01-21  14426.50
# 2022-01-24  14501.00
#
# [3981 rows x 1 columns]

# %%
nas.to_csv('nas.csv')

# %%
nas.head(25)
# Out:
#               Close
# Date
# 2006-04-06  1754.75
# 2006-04-07  1739.75
# 2006-04-10  1735.50
# 2006-04-11  1720.75
# 2006-04-12  1718.75
# 2006-04-13  1725.50
# 2006-04-17  1710.50
# 2006-04-18  1739.75
# 2006-04-19  1744.50
# 2006-04-20  1741.25
# 2006-04-21  1719.00
# 2006-04-24  1721.50
# 2006-04-25  1714.50
# 2006-04-26  1710.75
# 2006-04-27  1727.50
# 2006-04-28  1711.00
# 2006-05-01  1693.00
# 2006-05-02  1697.75
# 2006-05-03  1693.50
# 2006-05-04  1709.75
# 2006-05-05  1720.25
# 2006-05-08  1721.25
# 2006-05-09  1721.75
# 2006-05-10  1700.75
# 2006-05-11  1664.75

# %%
nas_fig = px.line(nas)
nas_fig.show()
# Out:
# <div>                            <div id="27ba957d-d9c7-47de-9462-de7d7547954c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27ba957d-d9c7-47de-9462-de7d7547954c")) {                    Plotly.newPlot(                        "27ba957d-d9c7-47de-9462-de7d7547954c",                        [{"hovertemplate": "variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Close", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Close", "showlegend": true, "type": "scattergl", "x": ["2006-04-06T00:00:00", "2006-04-07T00:00:00", "2006-04-10T00:00:00", "2006-04-11T00:00:00", "2006-04-12T00:00:00", "2006-04-13T00:00:00", "2006-04-17T00:00:00", "2006-04-18T00:00:00", "2006-04-19T00:00:00", "2006-04-20T00:00:00", "2006-0
# ...

# %%
#import cpi

# %%
#cpi.update()

# %%
#cpi.get(date(2006,04,06))
